# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('fastfood.csv')

# %%
df.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# 0     11     37.0    4.0   20.0     20.0  Other
# 1     18     46.0    6.0   20.0     20.0  Other
# 2     18     70.0   10.0   20.0     50.0  Other
# 3     18     55.0    6.0   25.0     20.0  Other
# 4     18     46.0    6.0   20.0     20.0  Other

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
df.describe()
# Out:
#           calories      cal_fat   total_fat     sat_fat   trans_fat  \
# count   515.000000   515.000000  515.000000  515.000000  515.000000
# mean    530.912621   238.813592   26.590291    8.153398    0.465049
# std     282.436147   166.407510   18.411876    6.418811    0.839644
# min      20.000000     0.000000    0.000000    0.000000    0.000000
# 25%     330.000000   120.000000   14.000000    4.000000    0.000000
# 50%     490.000000   210.000000   23.000000    7.000000    0.000000
# 75%     690.000000   310.000000   35.000000   11.000000    1.000000
# max    2430.000000  1270.000000  141.000000   47.000000    8.000000
#
#        cholesterol       sodium  total_carb       fiber       sugar  \
# count   515.000000   515.000000  515.000000  503.000000  515.000000
# mean     72.456311  1246.737864   45.664078    4.137177    7.262136
# std      63.160406   689.954278   24.883342    3.037460    6.761301
# min       0.000000    15.000000    0.000000    0.000000    0.000000
# 25%      35.000000   800.000000   28.500000    2.000000    3.000000
# 50%      60.000000  1110.000000   44.000000    3.000000    6.000000
# 75%      95.000000  1550.000000   57.000000    5.000000    9.000000
# max     805.000000  6080.000000  156.000000   17.000000   87.000000
#
#           protein       vit_a       vit_c     calcium
# count  514.000000  301.000000  305.000000  305.000000
# mean    27.891051   18.857143   20.170492   24.852459
# std     17.683921   31.384330   30.592243   25.522073
# min      1.000000    0.000000    0.000000    0.000000
# 25%     16.000000    4.000000    4.000000    8.000000
# 50%     24.500000   10.000000   10.000000   20.000000
# 75%     36.000000   20.000000   30.000000   30.000000
# max    186.000000  180.000000  400.000000  290.000000

# %%
df.columns
# Out:
# Index(['restaurant', 'item', 'calories', 'cal_fat', 'total_fat', 'sat_fat',
#        'trans_fat', 'cholesterol', 'sodium', 'total_carb', 'fiber', 'sugar',
#        'protein', 'vit_a', 'vit_c', 'calcium', 'salad'],
#       dtype='object')

# %%
df.restaurant.unique()
# Out:
# array(['Mcdonalds', 'Chick Fil-A', 'Sonic', 'Arbys', 'Burger King',
#        'Dairy Queen', 'Subway', 'Taco Bell'], dtype=object)

# %%
r_calories=df.groupby('restaurant').calories.mean().reset_index()

# %%
r_calories
# Out:
#     restaurant    calories
# 0        Arbys  532.727273
# 1  Burger King  608.571429
# 2  Chick Fil-A  384.444444
# 3  Dairy Queen  520.238095
# 4    Mcdonalds  640.350877
# 5        Sonic  631.698113
# 6       Subway  503.020833
# 7    Taco Bell  443.652174

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=df,y='restaurant',x='calories')
# Out:
# <AxesSubplot:xlabel='calories', ylabel='restaurant'>

# %%
mcd_info = df[df['restaurant'] == 'Mcdonalds']
plt.figure(figsize=(18, 10))
plt.title('McDonalds Calorie Per Item')
sns.barplot(y=mcd_info['item'], x=df['calories'])
# Out:
# <AxesSubplot:title={'center':'McDonalds Calorie Per Item'}, xlabel='calories', ylabel='item'>

# %%
for index, row in mcdonald_info.iterrows():
    if row['calories'] < 700:
        print(f"The {row['item']} is a item that is under 700 Calories")
# Out:
# The Artisan Grilled Chicken Sandwich is a item that is under 700 Calories
# The Big Mac is a item that is under 700 Calories
# The Cheeseburger is a item that is under 700 Calories
# The Classic Chicken Sandwich is a item that is under 700 Calories
# The Double Cheeseburger is a item that is under 700 Calories
# The Filet-O-Fish® is a item that is under 700 Calories
# The Garlic White Cheddar Burger is a item that is under 700 Calories
# The Grilled Garlic White Cheddar Chicken Sandwich is a item that is under 700 Calories
# The Hamburger is a item that is under 700 Calories
# The Lobster Roll is a item that is under 700 Calories
# The Maple Bacon Dijon 1/4 lb Burger is a item that is under 700 Calories
# The Grilled Maple Bacon Dijon Chicken Sandwich is a item that is under 700 Calories
# The McChicken is a item that is under 700 Calories
# The McDouble is a item that is under 700 Calories
# The McRib is a item that is under 700 Calories
# The Pico Guacamole 1/4 lb Burger is a item that is under 700 Calories
# The Grilled Pico Guacamole Chicken Sandwich is a item that is under 700 Calories
# The Crispy Pico Guacamole Chicken Sandwich is a item that is under 700 Calories
# The Premium Buttermilk Crispy Chicken Deluxe Sandwich is a item that is under 700 Calories
# The Premium Crispy Chicken Deluxe Sandwich is a item that is under 700 Calories
# The Quarter Pounder® with Cheese is a item that is under 700 Calories
# The Signature Sriracha Burger is a item that is under 700 Calories
# The Grilled Signature Sriracha Chicken Sandwich is a item that is under 700 Calories
# The Sweet BBQ Bacon 1/4 lb Burger is a item that is under 700 Calories
# The Grilled Sweet BBQ Bacon Chicken Sandwich is a item that is under 700 Calories
# The 3 piece Buttermilk Crispy Chicken Tenders is a item that is under 700 Calories
# The 4 piece Buttermilk Crispy Chicken Tenders is a item that is under 700 Calories
# The 4 Piece Chicken McNuggets is a item that is under 700 Calories
# The 6 Piece Chicken McNuggets is a item that is under 700 Calories
# The 10 Piece Chicken McNuggets is a item that is under 700 Calories
# The 4 piece Sweet N' Spicy Honey BBQ Glazed Tenders is a item that is under 700 Calories
# The Premium Asian Salad w/o Chicken is a item that is under 700 Calories
# The Premium Asian Salad w/ Grilled Chicken is a item that is under 700 Calories
# The Premium Asian Salad w/ Crispy Chicken is a item that is under 700 Calories
# The Premium Bacon Ranch Salad w/o Chicken is a item that is under 700 Calories
# The Premium Bacon Ranch Salad w/ Grilled Chicken is a item that is under 700 Calories
# The Premium Bacon Ranch Salad w/ Crispy Chicken is a item that is under 700 Calories
# The Premium Southwest Salad w/o Chicken is a item that is under 700 Calories
# The Premium Southwest Salad w/ Grilled Chicken is a item that is under 700 Calories
# The Premium Southwest Salad w/ Crispy Chicken is a item that is under 700 Calories

# %%
arbys_info = df[df['restaurant'] == 'Arbys']
plt.figure(figsize=(18, 10))
plt.title('Arbys Sodium Per Item by Mg')
sns.barplot(y=arbys_info['item'], x=df['sodium'])
# Out:
# <AxesSubplot:title={'center':'Arbys Sodium Per Item by Mg'}, xlabel='sodium', ylabel='item'>

# %%
low_sodium_arbys = df[(df['restaurant'] == 'Arbys') & (df['sodium'] < 600)]
plt.figure(figsize=(18, 6))
plt.title('Items under 600mg per serving')
sns.barplot(y=low_sodium_arbys['item'], x=low_sodium_arbys['sodium'])
# Out:
# <AxesSubplot:title={'center':'Items under 600mg per serving'}, xlabel='sodium', ylabel='item'>

# %%
df['health_score'] = 0

# %%
#Getting Sodium Points
for index, row in df.iterrows():
    if (row['sodium'] >= 200) and (row['sodium'] <= 400):
        df.at[index, 'health_score'] = row['health_score'] + 3
    elif (row['sodium'] >= 401) and (row['sodium'] <= 600):
        df.at[index, 'health_score'] = row['health_score'] + 2
    else:
        df.at[index, 'health_score'] = row['health_score'] + 1

# %%
for index, row in df.iterrows():
    if (row['protein'] >= 0) and (row['protein'] <= 15):
        df.at[index, 'health_score'] = row['health_score'] + 1
    elif (row['protein'] >= 16) and (row['protein'] <= 30):
        df.at[index, 'health_score'] = row['health_score'] + 2
    elif (row['protein'] > 30):
        df.at[index, 'health_score'] = row['health_score'] + 3

# %%
#Getting Calorie Health Points
for index, row in df.iterrows():
    if (row['calories'] >= 400) and (row['calories'] <= 700):
        df.at[index, 'health_score'] = row['health_score'] + 3
    else:
        df.at[index, 'health_score'] = row['health_score'] + 1

# %%
#Getting Sugar Health Points
for index, row in df.iterrows():
    if (row['sugar'] >= 0) and (row['sugar'] <= 16):
        df.at[index, 'health_score'] = row['health_score'] + 3
    elif (row['sugar'] >= 17) and (row['sugar'] <= 36):
        df.at[index, 'health_score'] = row['health_score'] + 2
    else:
        df.at[index, 'health_score'] = row['health_score'] + 1

# %%
healthscore_by_restaurant = df.groupby('restaurant')['health_score'].sum().reset_index()

# Create the bar plot
plt.figure(figsize=(18, 8))
plt.title('Total Health Score by Restaurant')
sns.barplot(x='restaurant', y='health_score', data=healthscore_by_restaurant)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='calories', y='cholesterol', data=df,color='blue')
plt.show()

# %%
# print(df[df['cholesterol'] > 750])
# print(df[df['calories'] > 2300])
df = df.drop(df.index[192])
df = df.drop(df.index[39])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(df[['calories']], df[['cholesterol']])

# generate the predicted values
x = np.linspace(df['calories'].min(), df['calories'].max())
y = reg.predict(x.reshape(-1,1))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='calories', y='cholesterol', data=df,color='blue')
plt.plot(x, y, color='red')
plt.title("Calories to Cholesterol Regression")
plt.show()
